# %% [markdown]
# # OKR - Presence Intention
# Currently right now we have static time values to determine what to do with our lights when presence is activated. This so far has proven frustrating as our Presence Intention changes day on day. For example, as thing have been at 8 am our Presence Intention is to go about a normal day, but as it is set in our system our Presence Intention is night time mode, assuming people are generally still sleeping
#
# # OKR - Electricity Usage
# - Explore Ratio of Electricity Usage to Presence Detection to see if presence detection logic can be optimized
#
# # OKR - Air Quality
# - Minimize air quality degredation spikes
