# %%
import requests
from pprint import pprint

# %%
response = requests.get(' http://homeassistant.mow/api/history/period/2025-03-30T00:00:00?filter_entity_id=sensor.prusaproto,sensor.i_9psl_carbon_dioxide&minimal_response=true', headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiI4NDZkYTk4N2NhZWU0M2M1ODViNDRmZTZjZmY5N2ZlNiIsImlhdCI6MTc0MzMxMjQwOSwiZXhwIjoyMDU4NjcyNDA5fQ.EdZOSzBc0jEfNTHhpC6bo730XpCTpZlB_xruWH2mGiI'

})
pprint(response.json())
# Out:
# [[{'attributes': {'device_class': 'enum', 'friendly_name': 'prusaproto'},
#    'entity_id': 'sensor.prusaproto',
#    'last_changed': '2025-03-30T07:00:00+00:00',
#    'last_updated': '2025-03-30T07:00:00+00:00',
#    'state': 'idle'},
#   {'last_changed': '2025-03-30T22:28:49.509938+00:00', 'state': 'busy'},
#   {'last_changed': '2025-03-30T22:29:19.509794+00:00', 'state': 'idle'},
#   {'last_changed': '2025-03-30T22:59:19.510432+00:00', 'state': 'attention'}],
#  [{'attributes': {'device_class': 'carbon_dioxide',
#                   'friendly_name': 'I-9PSL Carbon dioxide',
#                   'state_class': 'measurement',
#                   'unit_of_measurement': 'ppm'},
#    'entity_id': 'sensor.i_9psl_carbon_dioxide',
#    'last_changed': '2025-03-30T07:00:00+00:00',
#    'last_updated': '2025-03-30T07:00:00+00:00',
#    'state': '470'},
#   {'last_changed': '2025-03-30T07:00:35.135756+00:00', 'state': '469'},
# ...

# %%
import pandas as pd 

dataFrame = pd.read_json(response.json())
print(dataFrame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 import pandas as pd
# ----> 3 dataFrame = pd.read_json(response.json())
#       4 print(dataFrame)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:760, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     757 if convert_axes is None and orient != "table":
#     758     convert_axes = True
# --> 760 json_reader = JsonReader(
#     761     path_or_buf,
#     762     orient=orient,
#     763     typ=typ,
#     764     dtype=dtype,
#     765     convert_axes=convert_axes,
#     766     convert_dates=convert_dates,
#     767     keep_default_dates=keep_default_dates,
#     768     precise_float=precise_float,
# ...
